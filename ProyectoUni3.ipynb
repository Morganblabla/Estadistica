# %% [markdown]
# <a href="https://colab.research.google.com/github/Morganblabla/Estadistica/blob/main/ProyectoUni3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📊 Análisis de Series de Tiempo
# ## Estadística Inferencial II
#
# ---
#
# ### 📁 Proyecto: Relación entre Apple y Microsoft
# **Tema:** Estacionariedad, Estacionalidad y Regresión Polinomial
#
# ---
#
# ### 👨‍🎓 Alumnos:
# **Nombres:**
#
# Morgan Jiménez Paulina
#
# Cardona Sanchéz Zahira
# **Carrera:**
#
# Ingeniería en Gestión Empresarial
#
# **Matrícula:**
#
# 23150264
#
# 23150199
#
# ---
#
# ### 🏫 Instituto Tecnológico de Aguascalientes
# **Materia:** Estadística Inferencial II
# **Fecha de entrega:** [12/05/2025]
#
# ---
#
# ### 🔍 Descripción:
# Este trabajo presenta el análisis individual y comparativo de las series de tiempo de los precios de cierre de Apple y Microsoft, evaluando estacionariedad, estacionalidad y ajuste mediante regresión polinomial.
#
# ---

# %% [markdown]
# # Introducción
#
#
# Microsoft y Apple son dos de las empresas tecnológicas más importantes y conocidas del mundo. A lo largo de los años, ambas han crecido enormemente y se han convertido en referentes en sus respectivos campos: Microsoft con su software y servicios en la nube, y Apple con sus dispositivos como el iPhone, el iPad y las Mac. Pero más allá de sus productos, estas compañías también son muy observadas en el mundo financiero, ya que sus acciones se negocian en la bolsa y son parte importante del mercado global.
# Para poder entender cómo han evolucionado financieramente estas dos empresas, es útil usar una herramienta llamada análisis de series de tiempo. Esta técnica se utiliza para estudiar cómo cambian ciertos datos con el paso del tiempo. Por ejemplo, se puede observar cómo ha cambiado el precio de las acciones de Microsoft y Apple cada día, cada mes o cada año. Al mirar estos datos ordenados en el tiempo, podemos identificar si hay una tendencia general de crecimiento, si hay caídas importantes, si hay temporadas donde las acciones suben más o si ciertos eventos impactan de manera clara en el valor de las empresas.
# También se puede analizar cómo reaccionan estas empresas ante cambios en la economía, como crisis financieras o subidas de tasas de interés. A veces, una empresa puede ser más sensible que otra a estos cambios. El análisis de series de tiempo permite ver estas diferencias y entender mejor cómo se comportan las acciones de cada compañía frente a distintos escenarios.
# En resumen, comparar a Microsoft y Apple con esta herramienta no solo ayuda a ver qué tan rentables han sido, sino también a entender su comportamiento a lo largo del tiempo. Esto puede ser muy útil para quienes están interesados en invertir, hacer estudios económicos o simplemente entender cómo funcionan las grandes empresas tecnológicas en el mercado financiero.

# %% [markdown]
# # Marco Teórico
#
#
# Microsoft
#
# -Fundación y primeros años (1975–1989)
# Microsoft fue fundada el 4 de abril de 1975 por Bill Gates y Paul Allen en Albuquerque, Nuevo México. Su primer gran éxito fue MS-DOS, un sistema operativo que se convirtió en estándar en la industria de la computación durante los años 80. En 1985, lanzaron Windows, inicialmente una interfaz gráfica para MS-DOS, que eventualmente evolucionó en un sistema operativo independiente y dominante.
# -Consolidación y expansión (1990–2009)
# Durante esta etapa, Microsoft consolidó su posición en el mercado con productos como Windows 95, Windows XP y la suite Microsoft Office. En 2001, incursionó en el mercado de videojuegos con el lanzamiento de la consola Xbox. En 2008, introdujo Azure, su plataforma de servicios en la nube, marcando su entrada en el sector de la computación en la nube.
#  -Transformación bajo Satya Nadella (2014–2024)
# En 2014, Satya Nadella asumió el cargo de CEO, liderando una transformación significativa en la empresa. Microsoft adoptó una estrategia centrada en la nube y la inteligencia artificial, fortaleciendo su plataforma Azure y estableciendo una colaboración estratégica con OpenAI. En 2023, lanzó Copilot, un asistente de inteligencia artificial integrado en sus productos, utilizado por el 70% de las empresas del Fortune 500.
#
# -Adquisiciones y avances recientes (2023–2025)
# En octubre de 2023, Microsoft completó la adquisición de Activision Blizzard, incorporando franquicias como Call of Duty y World of Warcraft a su portafolio. En 2024, introdujo nuevas versiones de sus dispositivos Surface y lanzó Copilot+ PCs, integrando capacidades avanzadas de inteligencia artificial. En febrero de 2025, presentó el chip Majorana 1, abriendo nuevas posibilidades en la computación cuántica.
#
# -50 años de innovación (2025)
# El 4 de abril de 2025, Microsoft celebró su 50º aniversario, destacando su legado de innovación y su visión hacia el futuro. Durante el evento, se presentó la evolución de Copilot y se rindió homenaje a hitos históricos como el lanzamiento de Windows 95 y la consola Xbox.
#
#
# Apple
#
# -Fundación y primeros años (1976–1984)
# Apple fue fundada el 1 de abril de 1976 por Steve Jobs, Steve Wozniak y Ronald Wayne en el garaje de la casa de los padres de Jobs en Los Altos, California. Su primer producto, el Apple I, era un microordenador ensamblado a mano. En 1977, lanzaron el Apple II, uno de los primeros ordenadores personales de gran éxito comercial. En 1980, Apple salió a bolsa, convirtiéndose en una de las ofertas públicas iniciales más exitosas de la época.
#
# -Crecimiento, desafíos y retorno de Jobs (1985–1997)
# Tras el lanzamiento del Macintosh en 1984, que introdujo la interfaz gráfica de usuario al gran público, Apple enfrentó desafíos internos y competencia creciente. En 1985, Steve Jobs dejó la empresa debido a diferencias con la junta directiva. Durante su ausencia, Apple experimentó altibajos y una pérdida de cuota de mercado frente a competidores como Microsoft. En 1997, Apple adquirió NeXT, la empresa fundada por Jobs, lo que facilitó su regreso a la compañía.
#
#  -Renacimiento e innovación (1998–2011)
# Con el regreso de Jobs, Apple revitalizó su línea de productos, comenzando con la iMac en 1998. En 2001, lanzó el iPod, revolucionando la industria musical. En 2007, presentó el iPhone, que transformó la telefonía móvil y marcó el inicio de la era de los smartphones. Ese mismo año, la empresa cambió su nombre de Apple Computer, Inc. a Apple Inc., reflejando su enfoque más amplio en productos electrónicos de consumo.
#
# - Era post-Jobs y expansión (2011–2020)
# Tras el fallecimiento de Steve Jobs en 2011, Tim Cook asumió el cargo de CEO. Bajo su liderazgo, Apple continuó expandiendo su línea de productos con el lanzamiento del Apple Watch, AirPods y servicios como Apple Music y Apple Pay. La compañía también introdujo sus propios chips, como el M1, marcando una transición significativa en su arquitectura de hardware.
#
# - Desafíos y enfoque en inteligencia artificial (2021–2025)
# En los últimos años, Apple ha enfrentado críticas por quedarse rezagada en el desarrollo de inteligencia artificial generativa, especialmente en comparación con competidores como Google y Microsoft. Siri, su asistente virtual, ha sido objeto de escrutinio por su rendimiento limitado. La empresa ha iniciado esfuerzos para integrar IA en servicios como Safari y mejorar las capacidades de Siri, aunque persisten dudas sobre su capacidad para alcanzar a sus rivales.
# A pesar de estos desafíos, Apple ha mantenido un sólido desempeño financiero. En el primer trimestre de 2025, reportó ingresos por 124.300 millones de dólares, un aumento del 4% interanual, y ganancias por acción diluida de 2,40 dólares, un incremento del 10% respecto al año anterior.
# Además, la compañía anunció una inversión de más de 500.000 millones de dólares en Estados Unidos durante los próximos cuatro años, destinada a expandir su infraestructura, investigación y desarrollo, y capacidades de fabricación.
#
# -Situación actual en el mercado
# Al 9 de mayo de 2025, las acciones de Apple Inc. (AAPL) cotizan a 198,43 USD, con una capitalización de mercado de aproximadamente 3,28 billones de dólares. La empresa continúa siendo una de las más valiosas y reconocidas a nivel mundial.

# %% [markdown]
# 1.-  Se instaló la librería `alpha_vantage` y otras necesarias para manejar datos financieros. Se usó tu API key para obtener datos diarios de Apple y Microsoft desde el 1 de marzo de 2024 hasta el 1 de abril de 2025. Renombramos las columnas para distinguir entre ambas empresas y combinamos los datos en un solo DataFrame para compararlos fácilmente.

# %%
pip install alpha_vantage

# %% [markdown]
# #Apple

# %%
from alpha_vantage.timeseries import TimeSeries
import pandas as pd
import matplotlib.pyplot as plt
import yfinance as yf
import warnings
warnings.filterwarnings('ignore')

# Entra a https://www.alphavantage.co/support/#api-key
# Registrate para obtener tu api-key

# Tu clave de API (reemplaza esta por la tuya)
my_key = 'OAD5N4A29WFBL7Z2.'   # esta es mía, no la uses o habrá problemas

# Crear objeto TimeSeries
ts = TimeSeries(key=my_key, output_format='pandas')

# Obtener datos diarios de AMZN
ticker = 'AAPL'
data, meta = ts.get_daily(symbol=ticker, outputsize='full')

columnas = [ticker + '_' + i for i in ['Open', 'High', 'Low', 'Close', 'Volume']]
data.columns = columnas

inicio = '2024-03-01'
fin = '2025-04-01'
df1 = data[(data.index >= inicio) & (data.index <= fin)]

df1
# Out:
#             AAPL_Open  AAPL_High  AAPL_Low  AAPL_Close  AAPL_Volume
# date
# 2025-04-01    219.805     223.68  218.9000      223.19   36412740.0
# 2025-03-31    217.005     225.62  216.2300      222.13   65299321.0
# 2025-03-28    221.670     223.81  217.6800      217.90   39818617.0
# 2025-03-27    221.390     224.99  220.5601      223.85   37094774.0
# 2025-03-26    223.510     225.02  220.4700      221.53   34532656.0
# ...               ...        ...       ...         ...          ...
# 2024-03-07    169.150     170.73  168.4900      169.00   71765061.0
# 2024-03-06    171.060     171.24  168.6800      169.12   68587707.0
# 2024-03-05    170.760     172.04  169.6200      170.12   95132355.0
# 2024-03-04    176.150     176.90  173.7900      175.10   81510101.0
# 2024-03-01    179.550     180.53  177.3800      179.66   73563082.0
#
# [272 rows x 5 columns]

# %% [markdown]
# # Microsoft

# %%
from alpha_vantage.timeseries import TimeSeries
import pandas as pd
import matplotlib.pyplot as plt
import yfinance as yf
import warnings
warnings.filterwarnings('ignore')

# Entra a https://www.alphavantage.co/support/#api-key
# Registrate para obtener tu api-key

# Tu clave de API (reemplaza esta por la tuya)
my_key = 'OAD5N4A29WFBL7Z2.'   # esta es mía, no la uses o habrá problemas

# Crear objeto TimeSeries
ts = TimeSeries(key=my_key, output_format='pandas')

# Obtener datos diarios de AMZN
ticker = 'MSFT'
data, meta = ts.get_daily(symbol=ticker, outputsize='full')

columnas = [ticker + '_' + i for i in ['Open', 'High', 'Low', 'Close', 'Volume']]
data.columns = columnas

inicio = '2024-03-01'
fin = '2025-04-01'
df2 = data[(data.index >= inicio) & (data.index <= fin)]

df2
# Out:
#             MSFT_Open  MSFT_High  MSFT_Low  MSFT_Close  MSFT_Volume
# date
# 2025-04-01    374.650     382.85   373.230      382.19   19689503.0
# 2025-03-31    372.535     377.07   367.240      375.39   35184676.0
# 2025-03-28    388.080     389.13   376.930      378.80   21632016.0
# 2025-03-27    390.130     392.24   387.395      390.58   13766761.0
# 2025-03-26    395.000     395.31   388.570      389.97   16132906.0
# ...               ...        ...       ...         ...          ...
# 2024-03-07    406.120     409.78   402.240      409.14   18718479.0
# 2024-03-06    402.970     405.16   398.390      402.09   22344149.0
# 2024-03-05    413.960     414.25   400.640      402.65   26919177.0
# 2024-03-04    413.440     417.35   412.320      414.92   17595956.0
# 2024-03-01    411.270     415.87   410.880      415.50   17823445.0
#
# [272 rows x 5 columns]

# %%
# Comparativa
df = pd.merge(df1, df2, left_index=True, right_index=True)
df
# Out:
#             AAPL_Open  AAPL_High  AAPL_Low  AAPL_Close  AAPL_Volume  \
# date
# 2025-04-01    219.805     223.68  218.9000      223.19   36412740.0
# 2025-03-31    217.005     225.62  216.2300      222.13   65299321.0
# 2025-03-28    221.670     223.81  217.6800      217.90   39818617.0
# 2025-03-27    221.390     224.99  220.5601      223.85   37094774.0
# 2025-03-26    223.510     225.02  220.4700      221.53   34532656.0
# ...               ...        ...       ...         ...          ...
# 2024-03-07    169.150     170.73  168.4900      169.00   71765061.0
# 2024-03-06    171.060     171.24  168.6800      169.12   68587707.0
# 2024-03-05    170.760     172.04  169.6200      170.12   95132355.0
# 2024-03-04    176.150     176.90  173.7900      175.10   81510101.0
# 2024-03-01    179.550     180.53  177.3800      179.66   73563082.0
#
#             MSFT_Open  MSFT_High  MSFT_Low  MSFT_Close  MSFT_Volume
# date
# 2025-04-01    374.650     382.85   373.230      382.19   19689503.0
# ...

# %% [markdown]
# 2.- Se graficó los precios de cierre de Apple y Microsoft en el mismo gráfico, usando colores distintos para comparar visualmente su comportamiento a lo largo del tiempo.

# %%
# Graficar
plt.figure(figsize=(12, 6))
plt.plot(df['AAPL_Close'], label='Apple', color='blue')
plt.plot(df['MSFT_Close'], label='MSFT', color='purple')
plt.title('Precios de Cierre de AAPL y MSFT')
plt.xlabel('Fecha')
plt.ylabel('Precio de Cierre ($)')
plt.grid()
plt.legend()
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.show()

# %% [markdown]
# 3.- Se aplicastó la prueba de causalidad de Granger para ver si una acción predice a la otra.
# Primero se analiza si Apple afecta a Microsoft. Luego se probó si Microsoft afecta a Apple.

# %%
from statsmodels.tsa.stattools import grangercausalitytests

# Hipótesis Nula (H₀): La serie X no causa en el sentido de Granger a la serie Y.

# Hipótesis Alternativa (H₁): La serie X causa en el sentido de Granger a la serie Y.

# Definir el número máximo de rezagos para la prueba
max_lags = 7

# Realizar la prueba de causalidad de Granger
# La función devuelve resultados para varios tests y cada rezago hasta el máximo definido
resultado = grangercausalitytests(df[['AAPL_Close', 'MSFT_Close']], max_lags, verbose=True)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=9.8514  , p=0.0019  , df_denom=268, df_num=1
# ssr based chi2 test:   chi2=9.9617  , p=0.0016  , df=1
# likelihood ratio test: chi2=9.7830  , p=0.0018  , df=1
# parameter F test:         F=9.8514  , p=0.0019  , df_denom=268, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=5.2813  , p=0.0056  , df_denom=265, df_num=2
# ssr based chi2 test:   chi2=10.7618 , p=0.0046  , df=2
# likelihood ratio test: chi2=10.5529 , p=0.0051  , df=2
# parameter F test:         F=5.2813  , p=0.0056  , df_denom=265, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=4.3943  , p=0.0049  , df_denom=262, df_num=3
# ssr based chi2 test:   chi2=13.5351 , p=0.0036  , df=3
# likelihood ratio test: chi2=13.2056 , p=0.0042  , df=3
# parameter F test:         F=4.3943  , p=0.0049  , df_denom=262, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ...

# %% [markdown]
# Se acepta la Ho hasta el dìa 6 y 7. Apple afecta a Microsoft.

# %%
from statsmodels.tsa.stattools import grangercausalitytests

# Hipótesis Nula (H₀): La serie X no causa en el sentido de Granger a la serie Y.

# Hipótesis Alternativa (H₁): La serie X causa en el sentido de Granger a la serie Y.

# Definir el número máximo de rezagos para la prueba
max_lags = 7

# Realizar la prueba de causalidad de Granger
# La función devuelve resultados para varios tests y cada rezago hasta el máximo definido
resultado = grangercausalitytests(df[['MSFT_Close', 'AAPL_Close']], max_lags, verbose=True)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.3371  , p=0.2486  , df_denom=268, df_num=1
# ssr based chi2 test:   chi2=1.3521  , p=0.2449  , df=1
# likelihood ratio test: chi2=1.3487  , p=0.2455  , df=1
# parameter F test:         F=1.3371  , p=0.2486  , df_denom=268, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.8092  , p=0.4463  , df_denom=265, df_num=2
# ssr based chi2 test:   chi2=1.6489  , p=0.4385  , df=2
# likelihood ratio test: chi2=1.6439  , p=0.4396  , df=2
# parameter F test:         F=0.8092  , p=0.4463  , df_denom=265, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.4352  , p=0.2329  , df_denom=262, df_num=3
# ssr based chi2 test:   chi2=4.4207  , p=0.2195  , df=3
# likelihood ratio test: chi2=4.3848  , p=0.2228  , df=3
# parameter F test:         F=1.4352  , p=0.2329  , df_denom=262, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ...

# %% [markdown]
# No se rechaza la Ho nunca. Microsoft no afecta realmente a Apple.

# %% [markdown]
# # Apple

# %% [markdown]
# 4.- Se usa la librería Prophet para predecir el precio de cierre de Apple y Microsoft durante los próximos 365 días. Se ajustó el modelo con los datos históricos y generó gráficos que muestran la tendencia futura, el intervalo de incertidumbre y patrones semanales. Se observa una posible tendencia a la baja para ambas empresas en el futuro.

# %%
# !pip install prophet

# %%
from prophet import Prophet

# Crear el modelo y ajustarlo
modelo = Prophet()
modelo.fit(df1['AAPL_Close'].reset_index().rename(columns={'date': 'ds', 'AAPL_Close': 'y'}))

# Predicción para los próximos 365 días
futuro = modelo.make_future_dataframe(periods=365)
predicciones = modelo.predict(futuro)

# Visualizar las predicciones
fig = modelo.plot(predicciones)
plt.plot(df1['AAPL_Close'], label='Serie Original', color='red')
plt.xlabel('Fecha')
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.title('Predicción con Prophet')
plt.ylabel('Precio de Cierre ($)')
plt.legend()
fig = modelo.plot_components(predicciones)
# Out:
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpzlz_p07e/t1yzkx7h.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpzlz_p07e/tleju1q0.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=86566', 'data', 'file=/tmp/tmpzlz_p07e/t1yzkx7h.json', 'init=/tmp/tmpzlz_p07e/tleju1q0.json', 'output', 'file=/tmp/tmpzlz_p07e/prophet_modeljqxgdesd/prophet_model-20250509195009.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 19:50:09 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:50:09 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %% [markdown]
# # Microsoft

# %%
# !pip install prophet

# %%
from prophet import Prophet

# Crear el modelo y ajustarlo
modelo = Prophet()
modelo.fit(df2['MSFT_Close'].reset_index().rename(columns={'date': 'ds', 'MSFT_Close': 'y'}))

# Predicción para los próximos 365 días
futuro = modelo.make_future_dataframe(periods=365)
predicciones = modelo.predict(futuro)

# Visualizar las predicciones
fig = modelo.plot(predicciones)
plt.plot(df2['MSFT_Close'], label='Serie Original', color='red')
plt.xlabel('Fecha')
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.title('Predicción con Prophet')
plt.ylabel('Precio de Cierre ($)')
plt.legend()
fig = modelo.plot_components(predicciones)
# Out:
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpzlz_p07e/y1ao4is4.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpzlz_p07e/cxynqek1.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=20784', 'data', 'file=/tmp/tmpzlz_p07e/y1ao4is4.json', 'init=/tmp/tmpzlz_p07e/cxynqek1.json', 'output', 'file=/tmp/tmpzlz_p07e/prophet_modeljvegcii2/prophet_model-20250509195236.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 19:52:36 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:52:36 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %% [markdown]
# # Resultados
# Se realizó un análisis de series de tiempo con datos históricos de los precios de cierre de las acciones de Apple (AAPL) y Microsoft (MSFT) del 1 de marzo de 2024 al 1 de abril de 2025, obteniendo un total de 272 registros diarios por empresa.
#
#
#
# Los precios se visualizaron en una gráfica conjunta para comparar su evolución. Aunque ambos activos pertenecen al sector tecnológico y presentan comportamientos similares, sus precios difieren en magnitud y variabilidad.
#
#
#
# Para evaluar relaciones de dependencia entre las series, se aplicó la prueba de causalidad de Granger. Los resultados fueron los siguientes:
#
#
#
# Al analizar si Apple influye sobre Microsoft, se encontró evidencia significativa (p < 0.05) hasta el rezago 6, lo que indica que Apple tiene poder predictivo sobre Microsoft.
#
#
#
# En cambio, al probar si Microsoft influye sobre Apple, no se encontró evidencia significativa en ningún rezago (p > 0.05), por lo tanto, no se detectó causalidad en esa dirección.
#
#
#
# Finalmente, se empleó el modelo Prophet para generar predicciones de precios de cierre para los siguientes 365 días. En ambos casos, las predicciones mostraron una tendencia a la baja, con intervalos de incertidumbre cada vez más amplios a medida que se proyecta hacia el futuro.

# %% [markdown]
# # Conclusión
#
# A partir del análisis realizado sobre las series de tiempo de los precios de cierre de Apple y Microsoft, se puede concluir que la hipótesis planteada **“Como Apple y Microsoft pertenecen al mismo sector (tecnología), es muy probable que cuando a una le pase algo, poco después le pase lo mismo o algo similar a la otra.”** se cumple parcialmente. Los resultados de la prueba de causalidad de Granger indican que los movimientos en el precio de Apple sí influyen significativamente en los de Microsoft, mientras que no ocurre lo mismo en sentido contrario. Esto sugiere que Apple actúa como una empresa líder en este comportamiento bursátil.
#
# Además, mediante el modelo Prophet se observaron posibles tendencias a la baja para ambas acciones en el siguiente año, aunque con una considerable incertidumbre en las predicciones. En conjunto, estos resultados muestran que, si bien las dos compañías pertenecen al mismo sector y presentan trayectorias similares, sus interacciones no son completamente simétricas, y Apple parece tener un mayor peso en la dinámica compartida.

# %% [markdown]
# #Referencias Bibliograficas
#
# Momentos destacados en la historia de Microsoft – Centro de noticias. (2015, 6 abril). https://news.microsoft.com/es-es/2015/04/06/historia-microsoft-40-aniversario/
#
#
#
# Rautenstrauch, R. (2024, 23 julio). La historia de Microsoft. 1975 a 2024. Consultor 365. https://www.consultor365.com/ms/historia-microsoft-1975a2024/
#
#
#
# Chaparro, L. C. D. (2023, 2 julio). Apple y su camino para ser la empresa más poderosa del mundo. Portafolio.co. https://www.portafolio.co/negocios/empresas/apple-su-historia-y-su-camino-hasta-lograr-un-valor-de-mercado-de-3-billones-de-dolares-584471
#
#
#
# colaboradores de Wikipedia. (2025, 5 mayo). Apple. Wikipedia, la Enciclopedia Libre. https://es.wikipedia.org/wiki/Apple
